# %%
import therpy as tp
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### sample bec1 image

# %%
im = tp.Image('04-24-2018_14_21_27', lab='bec1')

# %%
im.plot_crop()
# Out:
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: divide by zero encountered in true_divide
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: invalid value encountered in true_divide
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: divide by zero encountered in log
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: invalid value encountered in log
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1232: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
im.lab
# Out:
# 'bec1'

# %% [markdown]
# ### sample fermi3 image

# %%
im = tp.Image('2018-04-27_19-02-05',lab='fermi3')

# %%
im.lab
# Out:
# 'fermi3'

# %%
im.plot_crop()
# Out:
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: divide by zero encountered in true_divide
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: invalid value encountered in true_divide
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: divide by zero encountered in log
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1493: RuntimeWarning: invalid value encountered in log
# /Users/biswaroopmukherjee/miniconda3/lib/python3.5/site-packages/therpy-0.3.4-py3.5.egg/therpy/funcs.py:1232: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
im.od
# Out:
# array([[        nan,        -inf,         nan, ...,         nan,
#         -0.        , -0.        ],
#        [-0.        ,         inf, -0.        , ...,        -inf,
#                 nan, -0.        ],
#        [        nan,        -inf,         nan, ...,         nan,
#                -inf,         nan],
#        ...,
#        [        nan,        -inf,         nan, ...,         nan,
#         -0.69314718,         nan],
#        [        inf, -0.        , -0.        , ..., -0.        ,
#         -0.        , -0.69314718],
#        [        nan,         nan,         nan, ..., -0.        ,
#         -0.        , -0.69314718]])
