# %%
import therpy as tp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline
# Out:
# Updating the local database...
# Done

# %% [markdown]
# ### sample bec1 image

# %%
im = tp.Image('08-15-2018_22_51_02_TopB', lab='bec1')

# %%
im.imshow()

# %%
im.lab
# Out:
# 'bec1'

# %% [markdown]
# ### sample fermi3 image

# %%
im = tp.Image('2018-04-27_19-02-05',lab='fermi3')

# %%
im.lab
# Out:
# 'fermi3'

# %%
im.imshow()
